# %%
import pandas as pd

# %%
pontuacao = pd.read_csv('dados_pilotos_pontuacao/temporada_2005.csv')
pontuacao.head()
# Out:
#    Pilotos      Pilotos.1  1AUS  2MYS  3BHR  4SMR  5ESP  6MCO  7EUR  8CAN  \
# 0  Pilotos        Pilotos  1AUS  2MYS  3BHR  4SMR  5ESP  6MCO  7EUR  8CAN
# 1       1.      F. ALONSO     6    10    10    10     8     5    10     -
# 2       2.   K. RAIKKONEN     1     -     6     -    10    10     -    10
# 3       3.  M. SCHUMACHER     -     2     -     8     -     2     4     8
# 4       4.     J. MONTOYA     3     5   NaN   NaN     2     4     2     -
#
#    ...  11GBR  12DEU  13HUN  14TUR  15ITA  16BEL  17BRA  18JPN  19CHN     Pts
# 0  ...  11GBR  12DEU  13HUN  14TUR  15ITA  16BEL  17BRA  18JPN  19CHN     Pts
# 1  ...      8     10      -      8      8      8      6      6     10  133.00
# 2  ...      6      -     10     10      5     10      8     10      8  112.00
# 3  ...      3      4      8      -      -      -      5      2      -   62.00
# 4  ...     10      8      -      6     10      -     10      -      -   60.00
#
# [5 rows x 22 columns]

# %%
pontuacao.columns = ['Pos.', 'Driver', 'AUS', 'MAL', 'BHR', 'SMR', 'ESP', 'MON', 'EUR',
       'CAN', 'USA‡', 'FRA', 'GBR', 'GER', 'HUN', 'TUR', 'ITA', 'BEL', 'BRA',
       'JPN', 'CHN', 'Points']
pontuacao.head()
# Out:
#       Pos.         Driver   AUS   MAL   BHR   SMR   ESP   MON   EUR   CAN  \
# 0  Pilotos        Pilotos  1AUS  2MYS  3BHR  4SMR  5ESP  6MCO  7EUR  8CAN
# 1       1.      F. ALONSO     6    10    10    10     8     5    10     -
# 2       2.   K. RAIKKONEN     1     -     6     -    10    10     -    10
# 3       3.  M. SCHUMACHER     -     2     -     8     -     2     4     8
# 4       4.     J. MONTOYA     3     5   NaN   NaN     2     4     2     -
#
#    ...    GBR    GER    HUN    TUR    ITA    BEL    BRA    JPN    CHN  Points
# 0  ...  11GBR  12DEU  13HUN  14TUR  15ITA  16BEL  17BRA  18JPN  19CHN     Pts
# 1  ...      8     10      -      8      8      8      6      6     10  133.00
# 2  ...      6      -     10     10      5     10      8     10      8  112.00
# 3  ...      3      4      8      -      -      -      5      2      -   62.00
# 4  ...     10      8      -      6     10      -     10      -      -   60.00
#
# [5 rows x 22 columns]

# %%
pontuacao = pontuacao.drop(pontuacao.index[0])
pontuacao.head()
# Out:
#   Pos.         Driver AUS MAL  BHR  SMR ESP MON EUR CAN  ... GBR GER HUN TUR  \
# 1   1.      F. ALONSO   6  10   10   10   8   5  10   -  ...   8  10   -   8
# 2   2.   K. RAIKKONEN   1   -    6    -  10  10   -  10  ...   6   -  10  10
# 3   3.  M. SCHUMACHER   -   2    -    8   -   2   4   8  ...   3   4   8   -
# 4   4.     J. MONTOYA   3   5  NaN  NaN   2   4   2   -  ...  10   8   -   6
# 5   5.  G. FISICHELLA  10   -    -    -   4   -   3   -  ...   5   5   -   5
#
#   ITA BEL BRA JPN CHN  Points
# 1   8   8   6   6  10  133.00
# 2   5  10   8  10   8  112.00
# 3   -   -   5   2   -   62.00
# 4  10   -  10   -   -   60.00
# 5   6   -   4   8   5   58.00
#
# [5 rows x 22 columns]

# %%
pontuacao.drop(['Pos.'], axis=1, inplace=True)

# %%
pontuacao = pontuacao.set_index('Driver')
pontuacao = pontuacao.T
pontuacao.head()
# Out:
# Driver F. ALONSO K. RAIKKONEN M. SCHUMACHER J. MONTOYA G. FISICHELLA  \
# AUS            6            1             -          3            10
# MAL           10            -             2          5             -
# BHR           10            6             -        NaN             -
# SMR           10            -             8        NaN             -
# ESP            8           10             -          2             4
#
# Driver R. SCHUMACHER J. TRULLI R. BARRICHELLO J. BUTTON M. WEBBER  ...  \
# AUS                -         -              8         -         4  ...
# MAL                4         8              -         -         -  ...
# BHR                5         8              -         -         3  ...
# SMR                -         4              -         -         2  ...
# ESP                5         6              -         -         3  ...
#
# Driver T. MONTEIRO A. WURZ N. KARTHIKEYAN C. ALBERS P. de la ROSA  \
# ...

# %%
pontuacao.shape[0]
# Out:
# 20

# %%
pontuacao.drop(pontuacao.index[[19]])
# Out:
# Driver F. ALONSO K. RAIKKONEN M. SCHUMACHER J. MONTOYA G. FISICHELLA  \
# AUS            6            1             -          3            10
# MAL           10            -             2          5             -
# BHR           10            6             -        NaN             -
# SMR           10            -             8        NaN             -
# ESP            8           10             -          2             4
# MON            5           10             2          4             -
# EUR           10            -             4          2             3
# CAN            -           10             8          -             -
# USA‡           -            -            10          -             -
# FRA           10            8             6          -             3
# GBR            8            6             3         10             5
# GER           10            -             4          8             5
# HUN            -           10             8          -             -
# ...

# %%
resultado.columns
# Out:
# Index(['Fernando Alonso', 'Kimi Räikkönen', 'Michael Schumacher',
#        'Juan Pablo Montoya', 'Giancarlo Fisichella', 'Ralf Schumacher',
#        'Jarno Trulli', 'Rubens Barrichello', 'Jenson Button', 'Mark Webber',
#        'Nick Heidfeld', 'David Coulthard', 'Felipe Massa',
#        'Jacques Villeneuve', 'Christian Klien', 'Tiago Monteiro',
#        'Alexander Wurz', 'Narain Karthikeyan', 'Christijan Albers',
#        'Pedro de la Rosa', 'Patrick Friesacher', 'Antônio Pizzonia',
#        'Takuma Sato', 'Vitantonio Liuzzi', 'Robert Doornbos',
#        'Anthony Davidson', 'Ricardo Zonta'],
#       dtype='object', name='Driver')

# %%
pontuacao.columns = ['Fernando Alonso', 'Kimi Räikkönen', 'Michael Schumacher',
       'Juan Pablo Montoya', 'Giancarlo Fisichella', 'Ralf Schumacher',
       'Jarno Trulli', 'Rubens Barrichello', 'Jenson Button', 'Mark Webber',
       'Nick Heidfeld', 'David Coulthard', 'Felipe Massa',
       'Jacques Villeneuve', 'Christian Klien', 'Tiago Monteiro',
       'Alexander Wurz', 'Narain Karthikeyan', 'Christijan Albers',
       'Pedro de la Rosa', 'Patrick Friesacher', 'Antônio Pizzonia',
       'Takuma Sato', 'Vitantonio Liuzzi', 'Robert Doornbos']

# %%
resultado = pd.read_csv('dados_pilotos_resultados/resultado_pilotos_temporada_2005.csv')
resultado.head()
# Out:
#   Pos.                Driver  AUS  MAL  BHR   SMR  ESP MON  EUR  CAN  ... GBR  \
# 0    1       Fernando Alonso   3F   1P   1P     1    2   4   1F  Ret  ...  2P
# 1    2        Kimi Räikkönen    8   9F    3  RetP   1P  1P  11†   1F  ...  3F
# 2    3    Michael Schumacher  Ret    7  Ret    2F  Ret  7F    5    2  ...   6
# 3    4    Juan Pablo Montoya    6    4  NaN   NaN    7   5    7  DSQ  ...   1
# 4    5  Giancarlo Fisichella   1P  Ret  Ret   Ret   5F  12    6  Ret  ...   4
#
#      GER  HUN  TUR ITA   BEL BRA  JPN  CHN Points
# 0      1   11    2   2     2  3P    3   1P    133
# 1  RetPF   1F   1P  4F     1  2F   1F   2F    112
# 2      5   2P  Ret  10   Ret   4    7  Ret     62
# 3      2  Ret   3F  1P  14P†   1  Ret  Ret     60
# 4      4    9    4   3   Ret   5    2    4     58
#
# [5 rows x 22 columns]

# %%
resultado.columns
# Out:
# Index(['Pos.', 'Driver', 'AUS', 'MAL', 'BHR', 'SMR', 'ESP', 'MON', 'EUR',
#        'CAN', 'USA‡', 'FRA', 'GBR', 'GER', 'HUN', 'TUR', 'ITA', 'BEL', 'BRA',
#        'JPN', 'CHN', 'Points'],
#       dtype='object')

# %%
resultado.drop(["Pos."], axis=1, inplace=True)

# %%
resultado = resultado.set_index('Driver')
resultado = resultado.T
resultado.head()
# Out:
# Driver Fernando Alonso Kimi Räikkönen Michael Schumacher Juan Pablo Montoya  \
# AUS                 3F              8                Ret                  6
# MAL                 1P             9F                  7                  4
# BHR                 1P              3                Ret                NaN
# SMR                  1           RetP                 2F                NaN
# ESP                  2             1P                Ret                  7
#
# Driver Giancarlo Fisichella Ralf Schumacher Jarno Trulli Rubens Barrichello  \
# AUS                      1P              12            9                  2
# MAL                     Ret               5            2                Ret
# BHR                     Ret               4            2                  9
# SMR                     Ret               9            5                Ret
# ESP                      5F               4            3                  9
#
# ...

# %%
resultado.drop(['Driver','Source:[13][14]'], axis=1, inplace=True)

# %%
resultado['Fernando Alonso'].unique()
# Out:
# array(['3F', '1P', '1', '2', '4', '1F', 'Ret', 'DNS', '2P', '11', '3P',
#        '3', '133'], dtype=object)

# %%
resultado.drop(resultado.index[19], inplace=True)

# %%
resultado.head()
# Out:
# Driver Fernando Alonso Kimi Räikkönen Michael Schumacher Juan Pablo Montoya  \
# AUS                 3F              8                Ret                  6
# MAL                 1P             9F                  7                  4
# BHR                 1P              3                Ret                NaN
# SMR                  1           RetP                 2F                NaN
# ESP                  2             1P                Ret                  7
#
# Driver Giancarlo Fisichella Ralf Schumacher Jarno Trulli Rubens Barrichello  \
# AUS                      1P              12            9                  2
# MAL                     Ret               5            2                Ret
# BHR                     Ret               4            2                  9
# SMR                     Ret               9            5                Ret
# ESP                      5F               4            3                  9
#
# ...

# %%
renomear = {'3F':'3', 
            '1P':'1',
            '1F':'1',
            '3P':'3',
            '9F':'9',
            'RetP':'Ret',
            '11†':'11',
            '2F':'2',
            '4F':'4',
            'RetPF':'Ret',
            '7F':'7',
            '2P':'2',
            '14P†':'14',
            '5F':'5',
            '7F':'7',
            '8P':'8',
            '13†':'13',
            '16†':'16',
            '14†':'14',
            '15†':'15'}

# %%
resultado = resultado.replace(renomear)

# %%
frequencia_alonso = resultado['Fernando Alonso'].value_counts()
frequencia_alonso
# Out:
# 1      7
# 2      5
# 3      3
# 4      1
# Ret    1
# DNS    1
# 11     1
# Name: Fernando Alonso, dtype: int64

# %%
percentual_alonso = resultado['Fernando Alonso'].value_counts(normalize=True) * 100
percentual_alonso
# Out:
# 1      36.842105
# 2      26.315789
# 3      15.789474
# 4       5.263158
# Ret     5.263158
# DNS     5.263158
# 11      5.263158
# Name: Fernando Alonso, dtype: float64

# %%
dist_alonso = pd.DataFrame({'Frequencia': frequencia_alonso, 'Porcentagem (%)': percentual_alonso})
dist_alonso.rename_axis('Posição', axis='columns', inplace=True)

# %%
dist_alonso
# Out:
# Posição  Frequencia  Porcentagem (%)
# 1                 7        36.842105
# 2                 5        26.315789
# 3                 3        15.789474
# 4                 1         5.263158
# Ret               1         5.263158
# DNS               1         5.263158
# 11                1         5.263158

# %%
frequencia_kimi = resultado['Kimi Räikkönen'].value_counts()
frequencia_kimi
# Out:
# 1      7
# 2      3
# 3      2
# Ret    2
# 8      1
# 9      1
# 11     1
# DNS    1
# 4      1
# Name: Kimi Räikkönen, dtype: int64

# %%
percentual_kimi = resultado['Kimi Räikkönen'].value_counts(normalize=True) * 100
percentual_kimi
# Out:
# 1      36.842105
# 2      15.789474
# 3      10.526316
# Ret    10.526316
# 8       5.263158
# 9       5.263158
# 11      5.263158
# DNS     5.263158
# 4       5.263158
# Name: Kimi Räikkönen, dtype: float64

# %%
dist_kimi = pd.DataFrame({'Frequencia': frequencia_kimi, 'Porcentagem (%)': percentual_kimi})
dist_kimi.rename_axis('Posição', axis='columns', inplace=True)

# %%
dist_kimi
# Out:
# Posição  Frequencia  Porcentagem (%)
# 1                 7        36.842105
# 2                 3        15.789474
# 3                 2        10.526316
# Ret               2        10.526316
# 8                 1         5.263158
# 9                 1         5.263158
# 11                1         5.263158
# DNS               1         5.263158
# 4                 1         5.263158

# %%
resultado.columns
# Out:
# Index(['Fernando Alonso', 'Kimi Räikkönen', 'Michael Schumacher',
#        'Juan Pablo Montoya', 'Giancarlo Fisichella', 'Ralf Schumacher',
#        'Jarno Trulli', 'Rubens Barrichello', 'Jenson Button', 'Mark Webber',
#        'Nick Heidfeld', 'David Coulthard', 'Felipe Massa',
#        'Jacques Villeneuve', 'Christian Klien', 'Tiago Monteiro',
#        'Alexander Wurz', 'Narain Karthikeyan', 'Christijan Albers',
#        'Pedro de la Rosa', 'Patrick Friesacher', 'Antônio Pizzonia',
#        'Takuma Sato', 'Vitantonio Liuzzi', 'Robert Doornbos',
#        'Anthony Davidson', 'Ricardo Zonta'],
#       dtype='object', name='Driver')

# %%
for piloto in resultado.columns:
    frequencia = resultado[piloto].value_counts()
    percentual = resultado[piloto].value_counts(normalize=True) * 100
    distribuicao = pd.DataFrame({'Frequencia': frequencia, 'Porcentagem (%)': percentual})
    distribuicao.rename_axis('Posição', axis='columns', inplace=True)
    print(piloto)
    print(distribuicao)
# Out:
# Fernando Alonso
# Posição  Frequencia  Porcentagem (%)
# 1                 7        36.842105
# 2                 5        26.315789
# 3                 3        15.789474
# 4                 1         5.263158
# Ret               1         5.263158
# DNS               1         5.263158
# 11                1         5.263158
# Kimi Räikkönen
# Posição  Frequencia  Porcentagem (%)
# 1                 7        36.842105
# 2                 3        15.789474
# 3                 2        10.526316
# Ret               2        10.526316
# 8                 1         5.263158
# 9                 1         5.263158
# 11                1         5.263158
# DNS               1         5.263158
# 4                 1         5.263158
# Michael Schumacher
# Posição  Frequencia  Porcentagem (%)
# Ret               6        31.578947
# 7                 3        15.789474
# 2                 3        15.789474
# 5                 2        10.526316
# 1                 1         5.263158
# ...

# %%
renomear = {'Ret': '0', 'DSQ': '0', 'DNS': '0', ' ': '0','WD':'0','DNSP':'0','NC':'0'}

# %%
novo_resultado = resultado.replace(renomear)

# %%
novo_resultado.head()
# Out:
# Driver Fernando Alonso Kimi Räikkönen Michael Schumacher Juan Pablo Montoya  \
# AUS                  3              8                  0                  6
# MAL                  1              9                  7                  4
# BHR                  1              3                  0                NaN
# SMR                  1              0                  2                NaN
# ESP                  2              1                  0                  7
#
# Driver Giancarlo Fisichella Ralf Schumacher Jarno Trulli Rubens Barrichello  \
# AUS                       1              12            9                  2
# MAL                       0               5            2                  0
# BHR                       0               4            2                  9
# SMR                       0               9            5                  0
# ESP                       5               4            3                  9
#
# ...

# %%
novo_resultado.fillna('0', inplace=True)

# %%
novo_resultado['Pedro de la Rosa'].astype(int, errors='raise')
# Out:
# AUS     0
# MAL     0
# BHR     5
# SMR     0
# ESP     0
# MON     0
# EUR     0
# CAN     0
# USA‡    0
# FRA     0
# GBR     0
# GER     0
# HUN     0
# TUR     0
# ITA     0
# BEL     0
# BRA     0
# JPN     0
# CHN     0
# Name: Pedro de la Rosa, dtype: int64

# %%
for coluna in novo_resultado.columns:
    print(novo_resultado[coluna].unique())
# Out:
# ['3' '1' '2' '4' '0' '11']
# ['8' '9' '3' '0' '1' '11' '2' '4']
# ['0' '7' '2' '5' '1' '3' '6' '10' '4']
# ['6' '4' '0' '7' '5' '1' '2' '3' '14']
# ['1' '0' '5' '12' '6' '4' '9' '3' '2']
# ['12' '5' '4' '9' '6' '0' '7' '8' '3']
# ['9' '2' '5' '3' '10' '8' '0' '14' '4' '6' '13' '15']
# ['2' '0' '9' '8' '3' '7' '10' '12' '5' '6' '11']
# ['11' '0' '10' '4' '5' '3' '8' '7']
# ['5' '0' '6' '7' '3' '12' '11' '14' '4']
# ['0' '3' '6' '10' '2' '14' '12' '11']
# ['4' '6' '8' '11' '0' '7' '10' '13' '15' '9']
# ['10' '7' '11' '9' '14' '4' '0' '8' '6']
# ['13' '0' '11' '4' '9' '8' '14' '15' '6' '12' '10']
# ['7' '8' '0' '15' '9' '13' '5']
# ['16' '12' '10' '13' '15' '3' '17' '8' '0' '11']
# ['0' '3']
# ['15' '11' '0' '12' '13' '16' '4' '14' '20']
# ['0' '13' '14' '17' '11' '5' '18' '19' '12' '16']
# ['0' '5']
# ['17' '0' '12' '18' '6' '19']
# ['0' '7' '15' '13']
# ['14' '0' '12' '11' '16' '8' '9' '10']
# ['0' '8' '9']
# ['0' '18' '13' '14']
# ['0']
# ['0']

# %%
novo_resultado[['Fernando Alonso', 'Kimi Räikkönen', 'Michael Schumacher',
       'Juan Pablo Montoya', 'Giancarlo Fisichella', 'Ralf Schumacher',
       'Jarno Trulli', 'Rubens Barrichello', 'Jenson Button', 'Mark Webber',
       'Nick Heidfeld', 'David Coulthard', 'Felipe Massa',
       'Jacques Villeneuve', 'Christian Klien', 'Tiago Monteiro',
       'Alexander Wurz', 'Narain Karthikeyan', 'Christijan Albers',
       'Pedro de la Rosa', 'Patrick Friesacher', 'Antônio Pizzonia',
       'Takuma Sato', 'Vitantonio Liuzzi', 'Robert Doornbos',
       'Anthony Davidson', 'Ricardo Zonta']].astype(int, errors='raise')
# Out:
# Driver  Fernando Alonso  Kimi Räikkönen  Michael Schumacher  \
# AUS                   3               8                   0
# MAL                   1               9                   7
# BHR                   1               3                   0
# SMR                   1               0                   2
# ESP                   2               1                   0
# MON                   4               1                   7
# EUR                   1              11                   5
# CAN                   0               1                   2
# USA‡                  0               0                   1
# FRA                   1               2                   3
# GBR                   2               3                   6
# GER                   1               0                   5
# HUN                  11               1                   2
# TUR                   2               1                   0
# ITA                   2               4                  10
# ...

# %%
novo_resultado = novo_resultado.astype(int)

# %%
novo_resultado
# Out:
# Driver  Fernando Alonso  Kimi Räikkönen  Michael Schumacher  \
# AUS                   3               8                   0
# MAL                   1               9                   7
# BHR                   1               3                   0
# SMR                   1               0                   2
# ESP                   2               1                   0
# MON                   4               1                   7
# EUR                   1              11                   5
# CAN                   0               1                   2
# USA‡                  0               0                   1
# FRA                   1               2                   3
# GBR                   2               3                   6
# GER                   1               0                   5
# HUN                  11               1                   2
# TUR                   2               1                   0
# ITA                   2               4                  10
# ...

# %%
novo_resultado = novo_resultado.replace(valor_pontuacao)

# %%
novo_resultado
# Out:
# Driver  Fernando Alonso  Kimi Räikkönen  Michael Schumacher  \
# AUS                   6               1                   0
# MAL                  10               9                   2
# BHR                  10               6                   0
# SMR                  10               0                   8
# ESP                   8              10                   0
# MON                   5              10                   2
# EUR                  10              11                   4
# CAN                   0              10                   8
# USA‡                  0               0                  10
# FRA                  10               8                   6
# GBR                   8               6                   3
# GER                  10               0                   4
# HUN                  11              10                   8
# TUR                   8              10                   0
# ITA                   8               5                  10
# ...

# %%
pontuacao.head(6)
# Out:
#     Fernando Alonso Kimi Räikkönen Michael Schumacher Juan Pablo Montoya  \
# AUS               6              1                  -                  3
# MAL              10              -                  2                  5
# BHR              10              6                  -                NaN
# SMR              10              -                  8                NaN
# ESP               8             10                  -                  2
# MON               5             10                  2                  4
#
#     Giancarlo Fisichella Ralf Schumacher Jarno Trulli Rubens Barrichello  \
# AUS                   10               -            -                  8
# MAL                    -               4            8                  -
# BHR                    -               5            8                  -
# SMR                    -               -            4                  -
# ESP                    4               5            6                  -
# ...

# %%
top_10 = ['Fernando Alonso', 'Kimi Räikkönen', 'Michael Schumacher',
       'Juan Pablo Montoya', 'Giancarlo Fisichella', 'Ralf Schumacher',
       'Jarno Trulli', 'Rubens Barrichello', 'Jenson Button', 'Mark Webber']

# %%
pontuacao_10_primeiros = pd.DataFrame(pontuacao[top_10])
pontuacao_10_primeiros
# Out:
#        Fernando Alonso Kimi Räikkönen Michael Schumacher Juan Pablo Montoya  \
# AUS                  6              1                  -                  3
# MAL                 10              -                  2                  5
# BHR                 10              6                  -                NaN
# SMR                 10              -                  8                NaN
# ESP                  8             10                  -                  2
# MON                  5             10                  2                  4
# EUR                 10              -                  4                  2
# CAN                  -             10                  8                  -
# USA‡                 -              -                 10                  -
# FRA                 10              8                  6                  -
# GBR                  8              6                  3                 10
# ...

# %%
pontuacao_10_primeiros['Fernando Alonso'].unique()
# Out:
# array(['6', '10', '8', '5', '-', '133.00'], dtype=object)

# %%
renomear = {'-': '0'}
pontuacao_10_primeiros = pontuacao_10_primeiros.replace(renomear)

# %%
pontuacao_10_primeiros.drop(pontuacao_10_primeiros.index[19], inplace=True)

# %%
pontuacao_10_primeiros.fillna('0', inplace=True)

# %%
pontuacao_10_primeiros = pontuacao_10_primeiros.astype(int)

# %%
print('___Posição Média de cada piloto:___')
for piloto in pontuacao_10_primeiros.columns:
    print(f'{piloto} -> {pontuacao_10_primeiros[piloto].mean():.2f}')
# Out:
# ___Posição Média de cada piloto:___
# Fernando Alonso -> 7.00
# Kimi Räikkönen -> 5.89
# Michael Schumacher -> 3.26
# Juan Pablo Montoya -> 3.16
# Giancarlo Fisichella -> 3.05
# Ralf Schumacher -> 2.37
# Jarno Trulli -> 2.26
# Rubens Barrichello -> 2.00
# Jenson Button -> 1.95
# Mark Webber -> 1.89
